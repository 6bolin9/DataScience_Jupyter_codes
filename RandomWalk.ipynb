# %% [markdown]
# # Random Walk Example

# %% [markdown]
# ## Step 1: Import Libraries

# %%
# %matplotlib notebook

import random
from matplotlib import pyplot as plt

# %% [markdown]
# ## Step 2: Generate Random Walk

# %%
# Starting position
position = 0

# Keep track of my positions
walk = [position]

# How many steps do I want to walk?
nsteps = 1000

# Do the walk
for i in range(nsteps):
    step = 1 if random.randint(0, 1) else -1
    position += step
    walk.append(position)

# Plot walk
plt.plot(walk)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# You can execute the cell above several times to see how the output changes.

# %%
def add(x, y):
    return x + y
print("3+5 is", add(3,5))
print("7+1 is", add(7,1))
print("3-2 is", add(3,-2))
# Out:
# 3+5 is 8
# 7+1 is 8
# 3-2 is 1

# %%
def increase_salary(old_salary, pet_increase):
    return old_salary * (1 + pet_increase / 100.)

# %%
salaries = [26500, 25000, 90000, 65000, 27000, 30000]

# %%
for salary in salaries:
    print (salary, increase_salary(salary, 20))
# Out:
# 26500 31800.0
# 25000 30000.0
# 90000 108000.0
# 65000 78000.0
# 27000 32400.0
# 30000 36000.0

# %%
import math

# %%
print(math.sqrt(25))
# Out:
# 5.0
